# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Q1. Ask the user to enter a value (e.g., M) for a mathematical function.
#     Generate x values from -10 to 10 using np.linspace().

import numpy as np
x=np.linspace(-10,10)
print(x,'\n')

#     Compute y values for:
#       y = M⋅x^2
#       y = M⋅sin(x)

M=int(input("Enter M:"))
y1=M*x**2
print('Y1=M*x^2\n',y1,'\n')
y2=M*np.sin(x)
print('Y2=M*sin(x)\n',y2,'\n')

# Plot both functions in a single figure:
#   Use different colors and line styles.
#   Add legend, grid, and title.


plt.plot(x,y1,'r--',label='Y1=M*x^2')
plt.plot(x,y2,'b-',label='Y2=M*sin(x)')
plt.legend()
plt.grid()
plt.title('Mathematical Functions')
plt.show()
# Out:
# [-10.          -9.59183673  -9.18367347  -8.7755102   -8.36734694
#   -7.95918367  -7.55102041  -7.14285714  -6.73469388  -6.32653061
#   -5.91836735  -5.51020408  -5.10204082  -4.69387755  -4.28571429
#   -3.87755102  -3.46938776  -3.06122449  -2.65306122  -2.24489796
#   -1.83673469  -1.42857143  -1.02040816  -0.6122449   -0.20408163
#    0.20408163   0.6122449    1.02040816   1.42857143   1.83673469
#    2.24489796   2.65306122   3.06122449   3.46938776   3.87755102
#    4.28571429   4.69387755   5.10204082   5.51020408   5.91836735
#    6.32653061   6.73469388   7.14285714   7.55102041   7.95918367
#    8.36734694   8.7755102    9.18367347   9.59183673  10.        ]
# Enter M: 100
# Y1=M*x^2
#  [1.00000000e+04 9.20033319e+03 8.43398584e+03 7.70095793e+03
#  7.00124948e+03 6.33486047e+03 5.70179092e+03 5.10204082e+03
#  4.53561016e+03 4.00249896e+03 3.50270721e+03 3.03623490e+03
#  2.60308205e+03 2.20324865e+03 1.83673469e+03 1.50354019e+03
#  1.20366514e+03 9.37109538e+02 7.03873386e+02 5.03956685e+02
#  3.37359434e+02 2.04081633e+02 1.04123282e+02 3.74843815e+01
#  4.16493128e+00 4.16493128e+00 3.74843815e+01 1.04123282e+02
#  2.04081633e+02 3.37359434e+02 5.03956685e+02 7.03873386e+02
#  9.37109538e+02 1.20366514e+03 1.50354019e+03 1.83673469e+03
#  2.20324865e+03 2.60308205e+03 3.03623490e+03 3.50270721e+03
#  4.00249896e+03 4.53561016e+03 5.10204082e+03 5.70179092e+03
#  6.33486047e+03 7.00124948e+03 7.70095793e+03 8.43398584e+03
#  9.20033319e+03 1.00000000e+04]
#
# Y2=M*sin(x)
#  [ 54.40211109  16.62827938 -23.87753156 -60.46033165 -87.10967035
#  -99.44713673 -95.44571997 -75.76284154 -43.63234265  -4.33317334
#   35.67792409  69.82723956  92.50413717  99.98286684  91.03469443
#   67.12977936  32.19563151  -8.02816748 -46.93296128 -78.12680235
#  -96.4846309  -98.99030764 -85.23215697 -57.47060412 -20.26679365
#   20.26679365  57.47060412  85.23215697  98.99030764  96.4846309
#   78.12680235  46.93296128   8.02816748 -32.19563151 -67.12977936
#  -91.03469443 -99.98286684 -92.50413717 -69.82723956 -35.67792409
#    4.33317334  43.63234265  75.76284154  95.44571997  99.44713673
#   87.10967035  60.46033165  23.87753156 -16.62827938 -54.40211109]

# %%
# Q.2 Create a dataset of five subjects and scores.
import pandas as pd
data={
    'Subject':['mathematics','physics','chemistry','english','computer science'],
    'Score':[87,88,96,86,89]
}
print(data)
#     Convert it into a Pandas DataFrame.
df=pd.DataFrame(data)
print(df)

#     Plot the scores using a Seaborn bar plot with:
sns.set_style('darkgrid')

#       Different colors for each bar.
ax=sns.barplot(x='Subject',y='Score',data=df,palette='deep',hue='Subject',legend=False)

#       Annotations on top of each bar.
for index, row in df.iterrows():
    ax.text(index, row.Score + 1, str(row.Score), ha='center')

#       Title, axis labels, and grid.
plt.title('Subjects vs Scores')
plt.xlabel('Subjects')
plt.ylabel('Scores')
plt.grid(axis='y')
plt.show()
# Out:
# {'Subject': ['mathematics', 'physics', 'chemistry', 'english', 'computer science'], 'Score': [87, 88, 96, 86, 89]}
#             Subject  Score
# 0       mathematics     87
# 1           physics     88
# 2         chemistry     96
# 3           english     86
# 4  computer science     89

# %%
# Q3. Write a Python script to select your roll number as seed for NumPy and
# then generate a dataset of 50 values using np.random.randn().
roll_number=102317102
np.random.seed(roll_number)

data=np.random.randn(50)
print(data)
# Create a 2x2 subplot layout displaying:
fig,axes = plt.subplots(2,2,figsize=(10, 8))

#   Line plot showing cumulative sum.
axes[0,0].plot(np.cumsum(data))
axes[0,0].set_title('Line plot showing cumulative sum.')
axes[0,0].set_xlabel('Indexes')
axes[0,0].set_ylabel('Cumulative Sums')
axes[0,0].grid(True)
#   Scatter plot with random noise.
x=np.linspace(0,10,50)
print(x)

axes[0,1].scatter(x,data)
axes[0,1].set_title('Scatter plot with random noise.')
axes[0,1].set_xlabel('X values')
axes[0,1].set_ylabel('Noise')
axes[0,1].grid(True)

# Customize with titles, axis labels, and grids.
axes[1,0].axis("off")
axes[1,1].axis("off")
# Out:
# [-2.63926360e-01 -7.37515955e-01  1.49588314e-01  1.47657809e+00
#   1.97824134e+00  1.81688187e+00  2.19048684e-01 -9.36350960e-01
#   3.52524847e-01 -7.17011141e-01 -3.16174831e-01  8.16626614e-01
#  -1.55717891e+00 -2.30515332e-01  8.87464182e-02 -7.86813756e-02
#  -7.22402373e-01  2.73929867e-01  8.90503181e-01 -7.28078551e-01
#  -6.53544852e-01 -9.27635183e-01 -1.92785873e+00 -4.96650069e-01
#  -1.04991762e-01  8.95078978e-01  1.15117080e+00 -7.19128810e-01
#   4.71942537e-01 -2.06141543e-01 -2.24678790e-01  5.62667850e-01
#   1.89445639e+00  4.77356619e-03 -1.21843101e+00 -2.00118383e-01
#   1.39276260e-01 -4.59186762e-01 -2.47569288e-01 -2.58988076e-01
#   1.95453365e+00  2.71053319e-01 -4.43788810e-04  1.58224374e+00
#   1.37111319e-01 -1.08324210e-03 -1.12518938e-01 -4.91189055e-01
#  -7.73012510e-01  9.21692882e-01]
# [ 0.          0.20408163  0.40816327  0.6122449   0.81632653  1.02040816
#   1.2244898   1.42857143  1.63265306  1.83673469  2.04081633  2.24489796
#   2.44897959  2.65306122  2.85714286  3.06122449  3.26530612  3.46938776
#   3.67346939  3.87755102  4.08163265  4.28571429  4.48979592  4.69387755
#   4.89795918  5.10204082  5.30612245  5.51020408  5.71428571  5.91836735
#   6.12244898  6.32653061  6.53061224  6.73469388  6.93877551  7.14285714
#   7.34693878  7.55102041  7.75510204  7.95918367  8.16326531  8.36734694
#   8.57142857  8.7755102   8.97959184  9.18367347  9.3877551   9.59183673
#   9.79591837 10.        ]
# (np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(1.0))

# %%
# Q.4 Download Data-set from the below link
#https://github.com/AnjulaMehto/MCA/blob/main/company_sales_data.csv
df1=pd.read_csv(r"C:\Users\agarw\Downloads\company_sales_data.csv")
df1.head()

# Apply ‘seaborn’ library to do the following.
# 1. Read Total profit of all months and show it using a line plot.
plt.figure(figsize=(10,6))
sns.lineplot(data=df1,x='month_number',y='total_profit')
plt.title('Total profit of all months')
plt.xlabel('Months')
plt.ylabel('Total profit')
plt.show()

print()

# 2. Read all product sales data and show it using a multiline plot.
plt.figure(figsize=(10,6))
products=df1.columns[1:-2]
for p in products:
  sns.lineplot(data=df1,x='month_number',y=p,label=p)

plt.title('product sales data')
plt.xlabel('Months')
plt.ylabel('Sales')
plt.show()

# 3. Plot bar chart for all the features/attributes.
plt.figure(figsize=(10,6))
products=df1[1:]
products.plot(kind='bar',figsize=(10,6))
plt.title('Bar chart')
plt.xlabel('Months')
plt.ylabel('Sales')
plt.show()
